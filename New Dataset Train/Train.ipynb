# %% [markdown]
# IMPORT LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# DATASET

# %%
train_dataset_path ='Dataset/train'
validation_dataset_path ='Dataset/test'

# %% [markdown]
# LOAD DATASET

# %%
IMG_WIDTH = 182
IMG_HEIGHT = 256
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 2609 images belonging to 5 classes.

# %% [markdown]
# LOAD VALIDATION DATASET

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 2609 images belonging to 5 classes.

# %% [markdown]
# LABEL MAPPING

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Acne
# 1 : Atopic Dermatitis
# 2 : Eczema Photos
# 3 : Seborrheic Keratoses
# 4 : Tinea Ringworm

# %% [markdown]
# SAMPLE TRAIN IMAGES

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# CNN

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=5, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()

# %% [markdown]
# MODEL SEQUENTIAL

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 178, 252, 128)     9728
#
#  activation_6 (Activation)   (None, 178, 252, 128)     0
#
#  max_pooling2d_6 (MaxPoolin  (None, 89, 126, 128)      0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 89, 126, 128)      512
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 87, 124, 64)       73792
#
#  activation_7 (Activation)   (None, 87, 124, 64)       0
#
#  max_pooling2d_7 (MaxPoolin  (None, 43, 62, 64)        0
#  g2D)
#
#  batch_normalization_7 (Bat  (None, 43, 62, 64)        256
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 41, 60, 32)        18464
#
#  activation_8 (Activation)   (None, 41, 60, 32)        0
#
#  max_pooling2d_8 (MaxPoolin  (None, 20, 30, 32)        0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 20, 30, 32)        128
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 19200)             0
#
#  dense_4 (Dense)             (None, 256)               4915456
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 5019621 (19.15 MB)
# Trainable params: 5019173 (19.15 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
optimizer = Adam(learning_rate=0.001)

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# EPOCH

# %%
history = cnn_model.fit(train_generator, epochs=30, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# 82/82 - 291s - loss: 10.3930 - accuracy: 0.3292 - val_loss: 3.9113 - val_accuracy: 0.3595 - lr: 0.0010 - 291s/epoch - 4s/step
# Epoch 2/30
# 82/82 - 319s - loss: 7.0379 - accuracy: 0.3714 - val_loss: 5.6053 - val_accuracy: 0.1594 - lr: 0.0010 - 319s/epoch - 4s/step
# Epoch 3/30
# 82/82 - 291s - loss: 4.0878 - accuracy: 0.3959 - val_loss: 1.8164 - val_accuracy: 0.4071 - lr: 0.0010 - 291s/epoch - 4s/step
# Epoch 4/30
# 82/82 - 289s - loss: 2.6252 - accuracy: 0.4323 - val_loss: 2.5003 - val_accuracy: 0.3388 - lr: 0.0010 - 289s/epoch - 4s/step
# Epoch 5/30
# 82/82 - 1051s - loss: 1.9331 - accuracy: 0.4573 - val_loss: 2.1512 - val_accuracy: 0.2871 - lr: 0.0010 - 1051s/epoch - 13s/step
# Epoch 6/30
# 82/82 - 297s - loss: 1.6158 - accuracy: 0.4868 - val_loss: 5.9150 - val_accuracy: 0.2154 - lr: 0.0010 - 297s/epoch - 4s/step
# Epoch 7/30
# 82/82 - 296s - loss: 1.5282 - accuracy: 0.4906 - val_loss: 2.3173 - val_accuracy: 0.4327 - lr: 0.0010 - 296s/epoch - 4s/step
# Epoch 8/30
# 82/82 - 299s - loss: 1.3578 - accuracy: 0.5105 - val_loss: 1.2829 - val_accuracy: 0.5297 - lr: 0.0010 - 299s/epoch - 4s/step
# Epoch 9/30
# 82/82 - 304s - loss: 1.1981 - accuracy: 0.5531 - val_loss: 2.0471 - val_accuracy: 0.3825 - lr: 0.0010 - 304s/epoch - 4s/step
# Epoch 10/30
# 82/82 - 293s - loss: 1.1646 - accuracy: 0.5439 - val_loss: 2.4423 - val_accuracy: 0.3952 - lr: 0.0010 - 293s/epoch - 4s/step
# Epoch 11/30
# 82/82 - 287s - loss: 1.1590 - accuracy: 0.5562 - val_loss: 0.9259 - val_accuracy: 0.6539 - lr: 0.0010 - 287s/epoch - 4s/step
# Epoch 12/30
# 82/82 - 306s - loss: 1.1118 - accuracy: 0.5776 - val_loss: 0.8411 - val_accuracy: 0.6704 - lr: 0.0010 - 306s/epoch - 4s/step
# Epoch 13/30
# 82/82 - 338s - loss: 1.0929 - accuracy: 0.5811 - val_loss: 0.8432 - val_accuracy: 0.7018 - lr: 0.0010 - 338s/epoch - 4s/step
# Epoch 14/30
# 82/82 - 328s - loss: 1.0664 - accuracy: 0.5918 - val_loss: 0.8190 - val_accuracy: 0.6750 - lr: 0.0010 - 328s/epoch - 4s/step
# Epoch 15/30
# 82/82 - 292s - loss: 1.0382 - accuracy: 0.5937 - val_loss: 1.3228 - val_accuracy: 0.5473 - lr: 0.0010 - 292s/epoch - 4s/step
# Epoch 16/30
# 82/82 - 5543s - loss: 1.0247 - accuracy: 0.6044 - val_loss: 1.5864 - val_accuracy: 0.3622 - lr: 0.0010 - 5543s/epoch - 68s/step
# Epoch 17/30
# 82/82 - 315s - loss: 1.0085 - accuracy: 0.6167 - val_loss: 1.1120 - val_accuracy: 0.6190 - lr: 0.0010 - 315s/epoch - 4s/step
# Epoch 18/30
# 82/82 - 490s - loss: 1.0403 - accuracy: 0.6087 - val_loss: 1.0630 - val_accuracy: 0.6121 - lr: 0.0010 - 490s/epoch - 6s/step
# Epoch 19/30
# 82/82 - 371s - loss: 0.9827 - accuracy: 0.6163 - val_loss: 1.2385 - val_accuracy: 0.5577 - lr: 0.0010 - 371s/epoch - 5s/step
# Epoch 20/30
# 82/82 - 275s - loss: 0.9112 - accuracy: 0.6451 - val_loss: 0.7533 - val_accuracy: 0.7263 - lr: 3.1623e-04 - 275s/epoch - 3s/step
# Epoch 21/30
# 82/82 - 298s - loss: 0.8650 - accuracy: 0.6673 - val_loss: 0.6551 - val_accuracy: 0.7493 - lr: 3.1623e-04 - 298s/epoch - 4s/step
# Epoch 22/30
# 82/82 - 325s - loss: 0.8259 - accuracy: 0.6869 - val_loss: 0.5431 - val_accuracy: 0.8260 - lr: 3.1623e-04 - 325s/epoch - 4s/step
# Epoch 23/30
# 82/82 - 286s - loss: 0.8059 - accuracy: 0.6876 - val_loss: 0.5392 - val_accuracy: 0.8294 - lr: 3.1623e-04 - 286s/epoch - 3s/step
# Epoch 24/30
# 82/82 - 305s - loss: 0.8016 - accuracy: 0.6941 - val_loss: 0.5447 - val_accuracy: 0.8172 - lr: 3.1623e-04 - 305s/epoch - 4s/step
# Epoch 25/30
# 82/82 - 335s - loss: 0.7962 - accuracy: 0.7018 - val_loss: 0.6331 - val_accuracy: 0.7731 - lr: 3.1623e-04 - 335s/epoch - 4s/step
# Epoch 26/30
# 82/82 - 312s - loss: 0.7705 - accuracy: 0.7095 - val_loss: 0.4478 - val_accuracy: 0.8505 - lr: 3.1623e-04 - 312s/epoch - 4s/step
# Epoch 27/30
# 82/82 - 286s - loss: 0.7396 - accuracy: 0.7091 - val_loss: 0.8925 - val_accuracy: 0.6267 - lr: 3.1623e-04 - 286s/epoch - 3s/step
# Epoch 28/30
# 82/82 - 286s - loss: 0.7314 - accuracy: 0.7194 - val_loss: 0.6828 - val_accuracy: 0.7627 - lr: 3.1623e-04 - 286s/epoch - 3s/step
# Epoch 29/30
# 82/82 - 298s - loss: 0.7079 - accuracy: 0.7336 - val_loss: 0.6455 - val_accuracy: 0.7597 - lr: 3.1623e-04 - 298s/epoch - 4s/step
# Epoch 30/30
# 82/82 - 299s - loss: 0.7313 - accuracy: 0.7175 - val_loss: 0.5437 - val_accuracy: 0.8018 - lr: 3.1623e-04 - 299s/epoch - 4s/step

# %% [markdown]
# MODEL METRICES

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# TEST MODEL

# %%
test_dataset = 'Dataset/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 2609 images belonging to 5 classes.

# %% [markdown]
# MODEL PREDICTIONS

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 82/82 [==============================] - 58s 698ms/step

# %% [markdown]
# TEST DATASET PREDICTIONS

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 82/82 [==============================] - 55s 674ms/step - loss: 0.5437 - accuracy: 0.8018

# %% [markdown]
# ACCURACY

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.5436806082725525
# Test Accuracy: 0.8018397688865662

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %% [markdown]
# CONFUSION MATRIX

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(5, 5)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#                       precision    recall  f1-score   support
#
#                 Acne       0.87      0.82      0.84       913
#    Atopic Dermatitis       0.87      0.58      0.69       400
#        Eczema Photos       0.74      0.84      0.78       400
# Seborrheic Keratoses       0.72      0.97      0.83       480
#       Tinea Ringworm       0.82      0.74      0.78       416
#
#             accuracy                           0.80      2609
#            macro avg       0.80      0.79      0.79      2609
#         weighted avg       0.81      0.80      0.80      2609

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
